# %% [markdown]
# # DV ASSIGNMENT 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
deliveries = pd.read_csv('deliveries.csv')
matches = pd.read_csv('matches.csv')

# %% [markdown]
# ## QUESTION 1  Match won by the maximum margin of runs

# %% [markdown]
# ### code

# %%
max_runs = matches['win_by_runs'].max()
matches.loc[matches['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %% [markdown]
# ### GRAPH

# %%
plt.figure(figsize=(15,6))
plt.plot(matches.index[::15], matches['win_by_runs'][::15], color='orange', label='Win by Runs')

plt.title('Win By Runs - All Matches')
plt.xlabel('Match Index')
plt.ylabel('Runs')
plt.legend()

plt.show()

# %% [markdown]
# ### Insights

# %% [markdown]
# #### 1. This is the highest winning margin by runs.

# %% [markdown]
# #### 2. The printed row shows complete match details

# %% [markdown]
# # Question 2) Match won by maximum wickets.

# %% [markdown]
# ## CODE

# %%
print(matches['win_by_wickets'].max())
print(matches.loc[matches['win_by_wickets'].idxmax()])
# Out:
# 10
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %% [markdown]
# ## GRAPH

# %%
plt.figure(figsize=(18,6))
plt.plot(matches.index[::15], matches['win_by_wickets'][::15], linestyle='-', color='blue')

plt.title('Win By Wickets - All Matches')
plt.xlabel('Match Index')
plt.ylabel('Wickets')

plt.show()

# %% [markdown]
# ## INSIGHT

# %% [markdown]
# #### 1. Some matches were completely dominated while chasing

# %% [markdown]
# #### 2.Maximum wickets win shows strong chasing performance.

# %% [markdown]
# # Question 3) Match won by the minimum margin of runs.

# %% [markdown]
# ## CODE

# %%
min_runs = matches['win_by_runs'].min()
matches.loc[matches['win_by_runs'].idxmin()]
# Out:
# id                                                       2
# season                                                2017
# city                                                  Pune
# date                                            2017-04-06
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %% [markdown]
# ## GRAPH

# %%
plt.figure(figsize=(15,6))
plt.hist(matches['win_by_runs'], bins=30, color='blue', edgecolor='black')

plt.title('Distribution of Win by Runs')
plt.xlabel('Runs')
plt.ylabel('Number of Matches')

plt.show()

# %% [markdown]
# ## INSIGHTS

# %% [markdown]
# #### 1. Most matches are won by small margin of runs

# %% [markdown]
# #### 2. Very large winning margins are less frequent

# %% [markdown]
# # Question 4) Match won by minimum wickets

# %% [markdown]
# ## Code:

# %%
min_wickets = matches['win_by_wickets'].min()
print(matches.loc[matches['win_by_wickets'].idxmin()])
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %% [markdown]
# ## Graph:

# %%
plt.figure(figsize=(10,5))
plt.hist(matches['win_by_wickets'], bins=10, color = 'pink' , edgecolor= 'black')
plt.title('Distribution of Win By Wickets (All Matches)')
plt.xlabel('Wickets')
plt.ylabel('Number of Matches')
plt.show()

# %% [markdown]
# ## Insight:

# %% [markdown]
# #### 1. Some matches were won with very small wicket margins, showing close finishes.

# %% [markdown]
# #### 2. Most matches are won by mid-range wicket margins rather than extreme values.

# %% [markdown]
# # Question 5) Matches where D/L method was and wasn't applied.

# %% [markdown]
# ## Code:

# %%
dl_counts = matches['dl_applied'].value_counts()
dl_applied = dl_counts.get(1, 0)
dl_not_applied = dl_counts.get(0, 0)
print("\nMatches where D/L Applied:", dl_applied)
print("Matches where D/L Not Applied:", dl_not_applied)
# Out:
# Matches where D/L Applied: 19
# Matches where D/L Not Applied: 737

# %% [markdown]
# ## GRAPH

# %%
plt.figure(figsize=(6,4))
plt.bar(['DL Applied','DL Not Applied'], [dl_applied, dl_not_applied], color=['blue','pink'])

plt.title('DL Method Usage in Matches')
plt.ylabel('Number of Matches')

plt.show()

# %% [markdown]
# ## Insight:

# %% [markdown]
# #### 1. DL method was applied in very few matches compared to normal matches.

# %% [markdown]
# #### 2. Most IPL matches were completed without rain interruption.

# %% [markdown]
# # Question 6) Number of matches held in each city.

# %% [markdown]
# ## code

# %%
city_counts = matches['city'].value_counts()
print(city_counts)
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %% [markdown]
# ## GRAPH:

# %%
plt.figure(figsize=(12,5))
plt.bar(city_counts.index, city_counts.values, color='pink')
plt.xticks(rotation=90)
plt.title('Matches Held in Each City')
plt.xlabel('City')
plt.ylabel('Number of Matches')
plt.show()

# %% [markdown]
# ## Insights:

# %% [markdown]
# #### 1. Few cities host majority of matches.

# %% [markdown]
# #### 2. Some cities hosted very few matches.

# %% [markdown]
# # Question 7) No. of matches won by each team.

# %% [markdown]
# ## code

# %%
team_wins = matches['winner'].value_counts()
print(team_wins)
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %% [markdown]
# ## GRAPH

# %%
plt.figure(figsize=(12,5))
plt.bar(team_wins.index, team_wins.values, color='GREY')
plt.xticks(rotation=90)
plt.title('Matches Won by Each Team')
plt.xlabel('Team')
plt.ylabel('Wins')
plt.show()

# %% [markdown]
# ## Insights:

# %% [markdown]
# #### 1. Some teams dominate the league.

# %% [markdown]
# #### 2. Few teams have very low wins.

# %% [markdown]
# # Question 8) Number of matches held in every season.

# %% [markdown]
# # CODE

# %%
season_matches = matches['season'].value_counts().sort_index()
print(season_matches)
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# 2018    60
# 2019    60
# Name: count, dtype: int64

# %% [markdown]
# ## GRAPH

# %%
plt.figure(figsize=(10,5))
plt.plot(season_matches.index, season_matches.values, marker='o', color='BLUE', linestyle='-')

plt.title('Matches Held Every Season')
plt.xlabel('Season')
plt.ylabel('Matches')

plt.show()

# %% [markdown]
# ## Insight:

# %% [markdown]
# #### 1. Number of matches increased over seasons.

# %% [markdown]
# #### 2. Some seasons had fewer matches.

# %% [markdown]
# # Question 9) Top 10 players based on number of man of match(MOM) awards won.

# %% [markdown]
# ##Code:

# %%
top_mom = matches['player_of_match'].value_counts().head(10)
print(top_mom)
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: count, dtype: int64

# %% [markdown]
# ## GRAPH

# %%
plt.figure(figsize=(10,5))
plt.bar(top_mom.index, top_mom.values, color='yellow')
plt.xticks(rotation=90)
plt.title('Top 10 Players - MOM Awards')
plt.xlabel('Player')
plt.ylabel('Awards')
plt.show()

# %% [markdown]
# ## INSIGHTS

# %% [markdown]
# #### 1. Few players dominate MOM awards.
# #### 2. Performance consistency matters.

# %% [markdown]
# # Question 10) Does winning toss mean winning match?

# %% [markdown]
# ## CODE

# %%
toss_win_match = matches[matches['toss_winner'] == matches['winner']]
result = toss_win_match.shape[0]
total = matches.shape[0]
print("Matches where Toss Winner won Match:", result)
print("Total Matches:", total)
# Out:
# Matches where Toss Winner won Match: 393
# Total Matches: 756

# %% [markdown]
# ## graph

# %%
plt.figure(figsize=(6,4))
plt.bar(['Won After Toss','Lost After Toss'], [result, total - result], color=['pink','purple'])

plt.title('Toss Impact on Match Result')
plt.ylabel('Matches')

plt.show()

# %% [markdown]
# ## Insights:

# %% [markdown]
# #### 1. Toss does not guarantee match win.
# #### 2. Many matches are won by toss-losing teams.

# %% [markdown]
# # Question 11) What was the decision taken by captains when they won the toss?

# %% [markdown]
# ## CODE

# %%
toss_decision = matches['toss_decision'].value_counts()
print(toss_decision)
# Out:
# toss_decision
# field    463
# bat      293
# Name: count, dtype: int64

# %% [markdown]
# ## graph

# %%
plt.figure(figsize=(6,4))
plt.bar(toss_decision.index, toss_decision.values,color=['grey','blue'])
plt.title('Toss Decisions')
plt.xlabel('Decision')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # INSIGHTS

# %% [markdown]
# #### 1. Teams prefer one strategy more.
# #### 2. Decision pattern shows match trend.

# %% [markdown]
# # Question 12) No. of matches where D/L method was applied every season.

# %% [markdown]
# ## Code:

# %%
dl_season = matches[matches['dl_applied']==1]['season'].value_counts().sort_index()
print(dl_season)
# Out:
# season
# 2008    2
# 2009    3
# 2011    3
# 2014    1
# 2015    2
# 2016    4
# 2017    1
# 2018    3
# Name: count, dtype: int64

# %% [markdown]
# ## Graph:

# %%
plt.figure(figsize=(10,5))
plt.plot(dl_season.index, dl_season.values, marker='o', linestyle='--', color='GREEN')

plt.title('DL Applied Every Season')
plt.xlabel('Season')
plt.ylabel('Matches')

plt.show()

# %% [markdown]
# ## Insights:
# #### 1. DL method applied rarely.
# #### 2. Some seasons had more rain impact

# %% [markdown]
# # Question 13) Different results for matches.
# ## Code:

# %%
results = matches['result'].value_counts()
print(results)
# Out:
# result
# normal       743
# tie            9
# no result      4
# Name: count, dtype: int64

# %% [markdown]
# ## Graph:

# %%
plt.figure(figsize=(6,4))
plt.bar(results.index, results.values, color=['purple','teal','gold'])

plt.title('Different Match Results')
plt.xlabel('Result Type')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# ## Insights:
# #### 1. Most matches end normally.
# #### 2. Few matches end in tie or no result.
# # Question 14) How many times did a team win the toss?
# ## Code

# %%
toss_wins = matches['toss_winner'].value_counts()
print(toss_wins)
# Out:
# toss_winner
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,5))
plt.bar(toss_wins.index, toss_wins.values, color='TEAL')
plt.xticks(rotation=90)
plt.title('Toss Wins by Teams')
plt.xlabel('Team')
plt.ylabel('Toss Wins')
plt.show()

# %% [markdown]
# ## Insights:
# #### 1. Toss wins are evenly distributed.
# #### 2. Some teams won toss more often.
# # Question 15) Best venue for defending & chasing a total.
# ## Code

# %%
defend = matches[matches['win_by_runs']>0]['venue'].value_counts().head(5)
chase = matches[matches['win_by_wickets']>0]['venue'].value_counts().head(5)
print("Best Defending Venues:\n", defend)
print("\nBest Chasing Venues:\n", chase)
# Out:
# Best Defending Venues:
#  venue
# Wankhede Stadium                   35
# Feroz Shah Kotla                   33
# Eden Gardens                       32
# MA Chidambaram Stadium, Chepauk    30
# M Chinnaswamy Stadium              30
# Name: count, dtype: int64
#
# Best Chasing Venues:
#  venue
# Eden Gardens              45
# M Chinnaswamy Stadium     40
# Wankhede Stadium          37
# Feroz Shah Kotla          33
# Sawai Mansingh Stadium    32
# Name: count, dtype: int64

# %% [markdown]
# ## Graph:
# #### a) Top Defending Venues.

# %%
plt.figure(figsize=(10,5))
plt.bar(defend.index, defend.values, color='skyblue')
plt.xticks(rotation=90)
plt.title('Top Defending Venues')
plt.show()

# %% [markdown]
# ## b) Top Chasing Venues.

# %%
plt.figure(figsize=(10,5))
plt.bar(chase.index, chase.values, color='orange')
plt.xticks(rotation=90)
plt.title('Top Chasing Venues')
plt.show()

# %% [markdown]
# ## Insights:
# #### 1. Some venues favour defending.
# #### 2. Some venues favour chasing.
# # Question 16) Best defending & chasing teams.
# ## Code:

# %%
best_defend = matches[matches['win_by_runs']>0]['winner'].value_counts().head(5)
best_chase = matches[matches['win_by_wickets']>0]['winner'].value_counts().head(5)
print("Best Defending Teams:\n", best_defend)
print("\nBest Chasing Teams:\n", best_chase)
# Out:
# Best Defending Teams:
#  winner
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Name: count, dtype: int64
#
# Best Chasing Teams:
#  winner
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Royal Challengers Bangalore    48
# Chennai Super Kings            48
# Rajasthan Royals               46
# Name: count, dtype: int64

# %% [markdown]
# ## Graph:
# ### a) Best Defending Teams.

# %%
plt.figure(figsize=(10,5))
plt.bar(best_defend.index, best_defend.values, color='hotpink')
plt.xticks(rotation=90)
plt.title('Best Defending Teams')
plt.show()

# %% [markdown]
# ### b) Best Chasing Teams.

# %%
plt.figure(figsize=(10,5))
plt.bar(best_chase.index, best_chase.values, color='lightpink')
plt.xticks(rotation=90)
plt.title('Best Chasing Teams')
plt.show()

# %% [markdown]
# ## Insights:
# #### 1. Some teams perform better while defending.
# #### 2. Some teams are strong chasers.
# # Question 17) Number of matches played in different stadiums.
# ## Code:

# %%
stadium_matches = matches['venue'].value_counts()
print(stadium_matches)
# Out:
# venue
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %% [markdown]
# ## Graph:

# %%
plt.figure(figsize=(12,5))
plt.bar(stadium_matches.index, stadium_matches.values,color='lightgreen')
plt.xticks(rotation=90)
plt.title('Matches in Different Stadiums')
plt.xlabel('Stadium')
plt.ylabel('Matches')
plt.show()

# %% [markdown]
# ## Insights:
# #### 1. Few stadiums host majority matches.
# #### 2. Many stadiums host limited matches.
# # Conclusion:

# %% [markdown]
# #### In this analysis of the IPL dataset, several aspects such as team performance, the influence of the toss, venue patterns, and the number of matches played in each season were examined. Graphs and basic statistical methods were used to visualize the data and identify meaningful patterns. These visualizations made it easier to interpret match outcomes and understand trends within the tournament. Overall, the analysis provides helpful insights into how different factors affect IPL matches and highlights important patterns across seasons.
#
# ## Thank You!
